# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns; sns.set(style='whitegrid')
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression

# %%
X, y = make_regression(n_features=1, bias=10, noise=40)
sns.scatterplot(X.ravel(), y)

# %%
m = LinearRegression()
m.fit(X, y)

sns.scatterplot(X.ravel(), y)

minimax = np.array([X.min(), X.max()])
plt.plot(minimax, m.predict(minimax.reshape(-1, 1)), 'r-')

plt.show()

# %%
m.coef_, m.intercept_
# Out:
# (array([94.8942103]), 14.136004686147418)

# %%
m.score(X, y)
# Out:
# 0.8826049423189074

# %%
X[:5]
# Out:
# array([[-0.11601217],
#        [-1.27812992],
#        [ 1.43915586],
#        [-0.84162497],
#        [ 1.49741796]])

# %%
dy = y - m.predict(X)
dy
# Out:
# array([-4.97808860e+00, -2.62890008e+01, -4.75781463e+01,  3.53679967e+01,
#        -3.76287860e+01, -3.00885837e+01, -1.54752116e+01, -2.42489185e+01,
#         1.10739013e+01,  1.78521821e+01, -6.28504948e-01, -4.40716359e+01,
#        -1.90543775e+01,  7.79416507e+01,  4.19434329e+01, -1.48689019e+01,
#         1.93368177e+01, -1.81867022e+01, -3.79402731e+01,  3.92315487e+01,
#         4.06225104e+01, -4.27647433e+01,  1.59746278e+01, -4.58920552e+01,
#        -1.72644579e+01,  2.74035348e+01,  4.45769619e+01,  6.72723609e+00,
#        -2.67336499e+01,  1.66064792e+01,  1.51045584e+01,  4.18479259e+01,
#         5.01077264e+01, -4.92495229e+01,  4.07315141e+01,  4.88295832e+01,
#         8.09165425e-01,  2.21822165e+01,  1.45151407e+01,  5.47626127e+01,
#         1.00226934e+00,  6.49391816e+00,  2.59954099e+01,  3.69106150e+00,
#        -4.58455910e+01, -2.57804731e+01,  2.76058804e+01, -2.36438914e+01,
#         3.13509595e+01,  5.57624829e+01,  3.61904900e+01,  1.56888493e+01,
#        -6.56205654e+00, -5.46829890e+01,  1.84676310e+01,  2.46711489e+01,
#         5.11433357e+01, -1.72350263e+01,  2.57821872e+01, -2.28677575e+01,
#        -1.75471762e+01, -1.33831193e+00, -5.24282278e+00, -1.36891681e+01,
#        -3.23398907e+01, -1.08453890e+02, -6.45190283e+01, -4.00258943e+01,
#        -2.16176643e+01, -2.03996198e+01, -3.42481032e+00,  1.01676442e+02,
#        -2.84209373e+00,  4.33353241e+01, -2.28509559e+01,  1.58613356e+01,
#         2.90307682e+01,  3.49344130e+01, -5.48395504e+00, -2.50503824e+01,
#        -6.21327969e+01,  1.90236068e+01,  9.64277449e+00,  1.99387252e+01,
#        -5.69913576e-03,  3.63711657e+00,  1.74066914e+01,  5.24843263e+01,
#        -5.63242963e+00, -3.06333099e+01, -1.57191529e+01, -3.80426155e+01,
#         2.22859536e+01,  2.85592154e+01, -4.41447700e+01, -3.81054958e+01,
#        -5.29202581e+01, -3.95481589e+01,  5.82110641e+01, -5.21530084e+01])

# %%
sns.distplot(dy)

# %%
stats.shapiro(dy)
# Out:
# (0.9890044331550598, 0.584919810295105)

# %%
dy.mean()
# Out:
# 2.9842794901924207e-15

# %%
stats.ttest_1samp(dy, 0)
# Out:
# Ttest_1sampResult(statistic=8.353990559203864e-16, pvalue=0.9999999999999993)

# %%
sns.scatterplot(X.ravel(), dy)

# %%
Xn = np.hstack([np.random.normal(0, 10, size=100).reshape(-1, 1), X])
m1 = LinearRegression()
m1.fit(Xn, y)
m1.coef_
# Out:
# array([-0.70867522, 95.69718658])

# %%
m1.score(Xn, y)
# Out:
# 0.8872258116360442

# %%
m.score(X, y)
# Out:
# 0.8826049423189074
